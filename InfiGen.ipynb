# %% [markdown]
# <a href="https://colab.research.google.com/github/kuhu14/InfiGen/blob/main/InfiGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install langchain

# %%
pip install agentneo
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 34.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 63.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 17.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.5/290.5 kB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.1/397.1 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 36.3 MB/s eta 0:00:00
# ...
#   Created wheel for GPUtil: filename=GPUtil-1.4.0-py3-none-any.whl size=7392 sha256=79bdc46cf9f383e1ee9fb9b08aa568e598aef77e582f89fdfbbca868a781fe8c
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built GPUtil
# ...

# %%
pip install langchain[all]
# Out:
# ...
# WARNING: langchain 0.2.17 does not provide the extra 'all'
# ...
# ^C

# %%
pip install --upgrade langchain
# Out:
# ...
#   Using cached langchain-0.3.8-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached langchain_core-0.3.21-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached langchain_text_splitters-0.3.2-py3-none-any.whl.metadata (2.3 kB)
# ...
# Using cached langchain-0.3.8-py3-none-any.whl (1.0 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 7.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.2.43
#     Uninstalling langchain-core-0.2.43:
#       Successfully uninstalled langchain-core-0.2.43
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.2.4
#     Uninstalling langchain-text-splitters-0.2.4:
#       Successfully uninstalled langchain-text-splitters-0.2.4
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.2.17
#     Uninstalling langchain-0.2.17:
#       Successfully uninstalled langchain-0.2.17
# ...

# %%
pip install langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 24.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 37.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# agentneo 1.2.1 requires langchain~=0.2.16, but you have langchain 0.3.8 which is incompatible.
# ...

# %%
pip install langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.5/389.5 kB 11.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.51.2
#     Uninstalling openai-1.51.2:
#       Successfully uninstalled openai-1.51.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# agentneo 1.2.1 requires langchain~=0.2.16, but you have langchain 0.3.8 which is incompatible.
# agentneo 1.2.1 requires openai~=1.51.2, but you have openai 1.55.0 which is incompatible.
# ...

# %%
pip install llama_index
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.0/189.0 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 21.7 MB/s eta 0:00:00
# ...

# %%
pip install llama_index --upgrade

# %%
pip uninstall llama_index

# %%
pip install llama_index

# %%
pip install git+https://github.com/jerryjliu/llama_index.git
# Out:
# ...
#   Cloning https://github.com/jerryjliu/llama_index.git to /tmp/pip-req-build-a9rtn4no
#   Running command git clone --filter=blob:none --quiet https://github.com/jerryjliu/llama_index.git /tmp/pip-req-build-a9rtn4no
#   Resolved https://github.com/jerryjliu/llama_index.git to commit 9c7ade75f331fe85af5c5549f4219910e995bd8b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
from agentneo import AgentNeo, Tracer, Evaluation, launch_dashboard
from langchain.agents import initialize_agent, AgentExecutor
from langchain.llms import OpenAI
from langchain.prompts import PromptTemplate  # Import PromptTemplate
from collections.abc import Sequence

# %%
pip install --upgrade agentneo
# Out:
# ...
#   Using cached openai-1.51.2-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached langchain-0.2.17-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached langchain_core-0.2.43-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached langchain_text_splitters-0.2.4-py3-none-any.whl.metadata (2.3 kB)
# ...
# Using cached langchain-0.2.17-py3-none-any.whl (1.0 MB)
# Using cached openai-1.51.2-py3-none-any.whl (383 kB)
# Using cached langchain_core-0.2.43-py3-none-any.whl (397 kB)
# Using cached langchain_text_splitters-0.2.4-py3-none-any.whl (25 kB)
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.55.0
#     Uninstalling openai-1.55.0:
#       Successfully uninstalled openai-1.55.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.21
#     Uninstalling langchain-core-0.3.21:
#       Successfully uninstalled langchain-core-0.3.21
#   Attempting uninstall: langchain-text-splitters
# ...

# %%
pip install openai==0.28
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.51.2
#     Uninstalling openai-1.51.2:
#       Successfully uninstalled openai-1.51.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# agentneo 1.2.1 requires openai~=1.51.2, but you have openai 0.28.0 which is incompatible.
# langchain-openai 0.2.9 requires langchain-core<0.4.0,>=0.3.17, but you have langchain-core 0.2.43 which is incompatible.
# langchain-openai 0.2.9 requires openai<2.0.0,>=1.54.0, but you have openai 0.28.0 which is incompatible.
# litellm 1.49.7 requires openai>=1.51.0, but you have openai 0.28.0 which is incompatible.
# llama-index-agent-openai 0.4.0 requires openai>=1.14.0, but you have openai 0.28.0 which is incompatible.
# ...

# %%
import openai

openai.api_key = "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"

try:
    response = openai.Engine.list()
    print("API Key is working!")
except Exception as e:
    print(f"Error: {e}")
# Out:
# API Key is working!

# %%
import time
import openai
from langchain.agents import Tool, create_openai_functions_agent
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI  # Using the LangChain's OpenAI wrapper directly
import os

# Set your OpenAI API key
openai.api_key = "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"

# Step 1: Define tool functions that will measure time taken to process requests
tool_times = []

def tool_function_1(x):
    start_time = time.time()  # Start timing
    response = f"Processed {x}"
    elapsed_time = time.time() - start_time  # End timing
    tool_times.append(elapsed_time)  # Track time for tool 1
    return response

def tool_function_2(x):
    start_time = time.time()  # Start timing
    response = f"Handled {x}"
    elapsed_time = time.time() - start_time  # End timing
    tool_times.append(elapsed_time)  # Track time for tool 2
    return response

tools = [
    Tool(name="Tool 1", func=tool_function_1, description="A simple processing tool"),
    Tool(name="Tool 2", func=tool_function_2, description="A simple handling tool")
]

# Define a simple prompt using PromptTemplate
prompt_template = """
You are a helpful assistant. You can use the following tools:
- Tool 1: {Tool 1}
- Tool 2: {Tool 2}

Your task is to process the given input and return a response using the available tools.
Input: {input}
Agent Scratchpad: {agent_scratchpad}
Response:
"""

prompt = PromptTemplate(input_variables=["Tool 1", "Tool 2", "input", "agent_scratchpad"], template=prompt_template)

# Step 2: Use LangChain's OpenAI wrapper directly
llm = OpenAI(model="text-davinci-003", temperature=0.7)  # Use LangChain's OpenAI model
agent = create_openai_functions_agent(
    llm=llm,
    tools=tools,
    prompt=prompt
)

# Step 3: Calculate the performance and evaluate
def evaluate_performance():
    # Calculate average tool response time manually
    average_response_time = sum(tool_times) / len(tool_times) if tool_times else 0
    print(f"Average Tool Response Time: {average_response_time} seconds")

    try:
        # This would be part of your evaluation logic (adjust as per your needs)
        print("Evaluation metrics calculated!")
    except ValueError as e:
        print(f"Evaluation error: {e}")

# Step 4: Run agent and measure performance
def run_agent():
    result = agent.run("How is the weather today?")
    print("Agent Response:", result)
    return result

# Run the agent and evaluate
run_agent()
evaluate_performance()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-4e9295d3727c> in <cell line: 5>()
#       3 from langchain.agents import Tool, create_openai_functions_agent
#       4 from langchain.prompts import PromptTemplate
# ----> 5 from langchain.llms import OpenAI  # Using the LangChain's OpenAI wrapper directly
#       6 import os
#       7
#
# /usr/local/lib/python3.10/dist-packages/langchain/llms/__init__.py in __getattr__(name)
#     563         return type_to_cls_dict
#     564     else:
# --> 565         return getattr(llms, name)
#     566
#     567
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/llms/__init__.py in __getattr__(name)
#     807         return _import_azure_openai()
#     808     elif name == "OpenAI":
# --> 809         return _import_openai()
#     810     elif name == "OpenAIChat":
#     811         return _import_openai_chat()
# ...
